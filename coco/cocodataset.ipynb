# %% [markdown]
# https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import skimage.io as io
from pycocotools.coco import COCO

# %% [markdown]
# ## Download the annotation files and set the path to "instances" annotations

# %% [markdown]
# https://cocodataset.org/#download

# %%
# -- macOS --
#dataDir = '/Users/khoingo/mlai/cocodataset'
# -- windows --
dataDir = 'D:\\khoi\\fourthbrain\\coco\\annotations_trainval2017'

dataType = 'val2017'

# -- macOS --
#annFile = '{}/annotations/instances_{}.json'.format(dataDir, dataType)
# -- windows --
annFile = '{}\\annotations\\instances_{}.json'.format(dataDir, dataType)

# %% [markdown]
# ## Expriment with the dataset

# %%
# initialize COCO api for instance annotations
coco = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=1.64s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# COCO categories:
# person bicycle car motorcycle airplane bus train truck boat traffic light fire hydrant stop sign parking meter bench bird cat dog horse sheep cow elephant bear zebra giraffe backpack umbrella handbag tie suitcase frisbee skis snowboard sports ball kite baseball bat baseball glove skateboard surfboard tennis racket bottle wine glass cup fork knife spoon bowl banana apple sandwich orange broccoli carrot hot dog pizza donut cake chair couch potted plant bed dining table toilet tv laptop mouse remote keyboard cell phone microwave oven toaster sink refrigerator book clock vase scissors teddy bear hair drier toothbrush
#
# COCO supercategories:
# kitchen outdoor sports indoor person accessory food furniture appliance vehicle electronic animal

# %% [markdown]
# ### Get all images for a set of categories

# %%
# get all images containing given categories
catIds = coco.getCatIds(catNms=['car']);
imgIds = coco.getImgIds(catIds=catIds);

# %%
catIds
# Out:
# [3]

# %%
len(imgIds)
# Out:
# 535

# %% [markdown]
# ### Get annotations, with iscrow=0 (single object instance segmentation)

# %%
annIds = coco.getAnnIds(imgIds=imgIds, catIds=catIds, iscrowd=0)

# %%
len(annIds)
# Out:
# 1918

# %%
# load annotations given annotation IDs
anns = coco.loadAnns(annIds)

# %%
anns[0]
# Out:
# {'segmentation': [[446.65,
#    301.37,
#    437.02,
#    302.04,
#    436.02,
#    301.54,
#    435.35,
#    297.72,
#    438.34,
#    296.89,
#    438.68,
#    294.73,
#    447.15,
#    294.23,
#    448.81,
#    298.05,
#    448.48,
#    301.04]],
#  'area': 82.66089999999997,
#  'iscrowd': 0,
#  'image_id': 532481,
#  'bbox': [435.35, 294.23, 13.46, 7.81],
#  'category_id': 3,
#  'id': 1342996}

# %% [markdown]
# ### Get images with 1 segmentation and area above some threshold

# %%
# get image ids
img_ids = [ann['image_id'] for ann in anns if ann['area'] > 30000 and len(ann['segmentation']) == 1]

# %%
len(img_ids)
# Out:
# 50

# %% [markdown]
# ### Load one sample image and show annotations

# %%
img_id = img_ids[0]

# %%
# load image
img = coco.loadImgs(ids=[img_id])[0]

# %%
img
# Out:
# {'license': 3,
#  'file_name': '000000454661.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2017/000000454661.jpg',
#  'height': 427,
#  'width': 640,
#  'date_captured': '2013-11-16 18:15:17',
#  'flickr_url': 'http://farm5.staticflickr.com/4008/4682770107_e89efb3ae2_z.jpg',
#  'id': 454661}

# %%
# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
I = io.imread(img['coco_url'])
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
# load and display instance annotations, only for specified categories
plt.imshow(I); plt.axis('off')
img_ann_ids = coco.getAnnIds(imgIds=[img_id], catIds=catIds)
img_anns = coco.loadAnns(img_ann_ids)
coco.showAnns(img_anns)

# %%
img_anns
# Out:
# [{'segmentation': [[368.36,
#     356.08,
#     498.47,
#     351.5,
#     633.17,
#     338.67,
#     639.58,
#     231.46,
#     591.02,
#     227.79,
#     549.79,
#     185.64,
#     350.03,
#     187.48,
#     295.97,
#     242.46,
#     280.39,
#     238.79,
#     268.48,
#     245.2,
#     276.73,
#     258.03,
#     247.4,
#     284.61,
#     254.73,
#     359.74]],
#   'area': 56297.64605000001,
#   'iscrowd': 0,
#   'image_id': 454661,
#   'bbox': [247.4, 185.64, 392.18, 174.1],
#   'category_id': 3,
#   'id': 134116},
#  {'segmentation': [[181.82,
#     210.29,
#     204.78,
#     207.53,
#     271.81,
#     207.53,
#     295.69,
#     214.88,
#     299.36,
#     220.39,
#     300.28,
#     222.22,
#     300.28,
#     225.9,
#     297.52,
#     231.41,
#     292.93,
#     236.92,
#     282.83,
#     236.92,
#     268.14,
#     244.26,
#     269.97,
#     249.77,
#     273.65,
#     252.53,
#     264.46,
#     258.95,
#     264.46,
#     264.46,
#     258.04,
#     270.89,
#     250.69,
#     275.48,
#     246.1,
#     282.83,
#     247.02,
#     293.85,
#     247.02,
#     302.11,
#     243.34,
#     314.05,
#     243.34,
#     317.72,
#     242.43,
#     320.48,
#     234.16,
#     323.23,
#     219.47,
#     323.23,
#     209.37,
#     324.15,
#     180.9,
#     316.81,
#     189.17,
#     293.85,
#     182.74,
#     290.18,
#     173.55,
#     270.89,
#     168.96,
#     258.04,
#     152.43,
#     243.34,
#     151.52,
#     243.34,
#     149.68,
#     236.92,
#     170.8,
#     212.12,
#     183.66,
#     211.2]],
#   'area': 10699.444349999998,
#   'iscrowd': 0,
#   'image_id': 454661,
#   'bbox': [149.68, 207.53, 150.6, 116.62],
#   'category_id': 3,
#   'id': 136684},
#  {'segmentation': [[180.23,
#     359.46,
#     177.59,
#     325.23,
#     177.59,
#     300.21,
#     176.93,
#     285.72,
#     165.08,
#     267.95,
#     153.89,
#     254.12,
#     141.38,
#     244.9,
#     145.99,
#     221.2,
#     138.09,
#     209.35,
#     120.31,
#     210.67,
#     103.19,
#     196.84,
#     92.0,
#     192.89,
#     84.1,
#     189.6,
#     74.22,
#     187.62,
#     53.81,
#     184.99,
#     26.82,
#     184.99,
#     13.65,
#     185.65,
#     0.0,
#     186.31,
#     0.49,
#     373.29]],
#   'area': 28391.276699999995,
#   'iscrowd': 0,
#   'image_id': 454661,
#   'bbox': [0.0, 184.99, 180.23, 188.3],
#   'category_id': 3,
#   'id': 137943}]

# %%
len(img_anns)
# Out:
# 3

# %% [markdown]
# ### Show image URLs

# %%
imgs = coco.loadImgs(ids=img_ids)

# %%
for im in imgs:
    print(im['coco_url'])
# Out:
# http://images.cocodataset.org/val2017/000000454661.jpg
# http://images.cocodataset.org/val2017/000000397351.jpg
# http://images.cocodataset.org/val2017/000000114770.jpg
# http://images.cocodataset.org/val2017/000000442456.jpg
# http://images.cocodataset.org/val2017/000000010363.jpg
# http://images.cocodataset.org/val2017/000000446651.jpg
# http://images.cocodataset.org/val2017/000000172330.jpg
# http://images.cocodataset.org/val2017/000000172330.jpg
# http://images.cocodataset.org/val2017/000000383289.jpg
# http://images.cocodataset.org/val2017/000000579902.jpg
# http://images.cocodataset.org/val2017/000000543043.jpg
# http://images.cocodataset.org/val2017/000000336232.jpg
# http://images.cocodataset.org/val2017/000000151962.jpg
# http://images.cocodataset.org/val2017/000000354753.jpg
# http://images.cocodataset.org/val2017/000000230008.jpg
# http://images.cocodataset.org/val2017/000000076417.jpg
# http://images.cocodataset.org/val2017/000000215723.jpg
# http://images.cocodataset.org/val2017/000000508602.jpg
# http://images.cocodataset.org/val2017/000000023272.jpg
# http://images.cocodataset.org/val2017/000000017178.jpg
# http://images.cocodataset.org/val2017/000000338718.jpg
# http://images.cocodataset.org/val2017/000000260925.jpg
# http://images.cocodataset.org/val2017/000000461751.jpg
# http://images.cocodataset.org/val2017/000000183246.jpg
# http://images.cocodataset.org/val2017/000000078823.jpg
# http://images.cocodataset.org/val2017/000000396338.jpg
# http://images.cocodataset.org/val2017/000000396338.jpg
# http://images.cocodataset.org/val2017/000000033854.jpg
# http://images.cocodataset.org/val2017/000000033854.jpg
# http://images.cocodataset.org/val2017/000000416885.jpg
# http://images.cocodataset.org/val2017/000000058539.jpg
# http://images.cocodataset.org/val2017/000000167122.jpg
# http://images.cocodataset.org/val2017/000000466156.jpg
# http://images.cocodataset.org/val2017/000000394510.jpg
# http://images.cocodataset.org/val2017/000000263463.jpg
# http://images.cocodataset.org/val2017/000000560474.jpg
# http://images.cocodataset.org/val2017/000000097679.jpg
# http://images.cocodataset.org/val2017/000000263594.jpg
# http://images.cocodataset.org/val2017/000000228942.jpg
# http://images.cocodataset.org/val2017/000000421455.jpg
# http://images.cocodataset.org/val2017/000000206487.jpg
# http://images.cocodataset.org/val2017/000000009891.jpg
# http://images.cocodataset.org/val2017/000000530099.jpg
# http://images.cocodataset.org/val2017/000000368335.jpg
# http://images.cocodataset.org/val2017/000000138979.jpg
# http://images.cocodataset.org/val2017/000000493286.jpg
# http://images.cocodataset.org/val2017/000000055150.jpg
# http://images.cocodataset.org/val2017/000000055150.jpg
# http://images.cocodataset.org/val2017/000000542625.jpg
# http://images.cocodataset.org/val2017/000000065485.jpg
