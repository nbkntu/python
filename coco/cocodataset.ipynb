# %% [markdown]
# https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import skimage.io as io
from pycocotools.coco import COCO

# %% [markdown]
# ## Download the annotation files and set the path to "instances" annotations

# %% [markdown]
# https://cocodataset.org/#download

# %%
# -- macOS --
dataDir = '/Users/khoingo/mlai/cocodataset'
# -- windows --
#dataDir = 'D:\\khoi\\fourthbrain\\coco\\annotations_trainval2017'

dataType = 'val2017'

# -- macOS --
annFile = '{}/annotations/instances_{}.json'.format(dataDir, dataType)
# -- windows --
#annFile = '{}\\annotations\\instances_{}.json'.format(dataDir, dataType)

# %% [markdown]
# ## Expriment with the dataset

# %%
# initialize COCO api for instance annotations
coco = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# COCO categories:
# person bicycle car motorcycle airplane bus train truck boat traffic light fire hydrant stop sign parking meter bench bird cat dog horse sheep cow elephant bear zebra giraffe backpack umbrella handbag tie suitcase frisbee skis snowboard sports ball kite baseball bat baseball glove skateboard surfboard tennis racket bottle wine glass cup fork knife spoon bowl banana apple sandwich orange broccoli carrot hot dog pizza donut cake chair couch potted plant bed dining table toilet tv laptop mouse remote keyboard cell phone microwave oven toaster sink refrigerator book clock vase scissors teddy bear hair drier toothbrush
#
# COCO supercategories:
# vehicle appliance accessory furniture kitchen animal sports electronic outdoor indoor food person

# %% [markdown]
# ### Get all images for a set of categories

# %%
# get all images containing given categories
catIds = coco.getCatIds(catNms=['refrigerator']);
imgIds = coco.getImgIds(catIds=catIds);

# %%
catIds
# Out:
# [82]

# %%
len(imgIds)
# Out:
# 101

# %% [markdown]
# ### Get annotations, with iscrow=0 (single object instance segmentation)

# %%
annIds = coco.getAnnIds(imgIds=imgIds, catIds=catIds, iscrowd=0)

# %%
len(annIds)
# Out:
# 126

# %%
# load annotations given annotation IDs
anns = coco.loadAnns(annIds)

# %%
anns[0]
# Out:
# {'segmentation': [[501.23,
#    124.65,
#    490.18,
#    347.65,
#    502.24,
#    348.65,
#    506.26,
#    335.59,
#    518.31,
#    328.56,
#    523.33,
#    321.53,
#    569.54,
#    326.55,
#    583.6,
#    342.62,
#    596.66,
#    352.67,
#    610.72,
#    323.54,
#    622.77,
#    321.53,
#    635.83,
#    117.62,
#    617.75,
#    114.61,
#    541.41,
#    111.59,
#    505.25,
#    115.61]],
#  'area': 29000.021499999995,
#  'iscrowd': 0,
#  'image_id': 30213,
#  'bbox': [490.18, 111.59, 145.65, 241.08],
#  'category_id': 82,
#  'id': 333104}

# %% [markdown]
# ### Get images with 1 segmentation and area above some threshold

# %%
# get image ids
img_ids = [ann['image_id'] for ann in anns if ann['area'] > 30000 and len(ann['segmentation']) == 1]

# %%
len(img_ids)
# Out:
# 41

# %% [markdown]
# ### Load one sample image and show annotations

# %%
img_id = img_ids[0]

# %%
# load image
img = coco.loadImgs(ids=[img_id])[0]

# %%
img
# Out:
# {'license': 4,
#  'file_name': '000000429598.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2017/000000429598.jpg',
#  'height': 480,
#  'width': 640,
#  'date_captured': '2013-11-14 16:19:13',
#  'flickr_url': 'http://farm8.staticflickr.com/7162/6617685485_877d5cee57_z.jpg',
#  'id': 429598}

# %%
# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
I = io.imread(img['coco_url'])
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
# load and display instance annotations, only for specified categories
plt.imshow(I); plt.axis('off')
img_ann_ids = coco.getAnnIds(imgIds=[img_id], catIds=catIds)
img_anns = coco.loadAnns(img_ann_ids)
coco.showAnns(img_anns)

# %%
img_anns
# Out:
# [{'segmentation': [[4.32,
#     117.3,
#     160.0,
#     107.57,
#     191.35,
#     475.14,
#     31.35,
#     474.05,
#     10.81,
#     338.92,
#     25.95,
#     331.35,
#     0.0,
#     118.38,
#     6.49,
#     119.46]],
#   'area': 57892.938500000004,
#   'iscrowd': 0,
#   'image_id': 429598,
#   'bbox': [0.0, 107.57, 191.35, 367.57],
#   'category_id': 82,
#   'id': 331603}]

# %%
len(img_anns)
# Out:
# 1

# %% [markdown]
# ### Show image URLs

# %%
imgs = coco.loadImgs(ids=img_ids)

# %%
for im in imgs:
    print(im['coco_url'])
# Out:
# http://images.cocodataset.org/val2017/000000429598.jpg
# http://images.cocodataset.org/val2017/000000159791.jpg
# http://images.cocodataset.org/val2017/000000446522.jpg
# http://images.cocodataset.org/val2017/000000537672.jpg
# http://images.cocodataset.org/val2017/000000215114.jpg
# http://images.cocodataset.org/val2017/000000073326.jpg
# http://images.cocodataset.org/val2017/000000170116.jpg
# http://images.cocodataset.org/val2017/000000349837.jpg
# http://images.cocodataset.org/val2017/000000349837.jpg
# http://images.cocodataset.org/val2017/000000243344.jpg
# http://images.cocodataset.org/val2017/000000168593.jpg
# http://images.cocodataset.org/val2017/000000168593.jpg
# http://images.cocodataset.org/val2017/000000117908.jpg
# http://images.cocodataset.org/val2017/000000194724.jpg
# http://images.cocodataset.org/val2017/000000435880.jpg
# http://images.cocodataset.org/val2017/000000459954.jpg
# http://images.cocodataset.org/val2017/000000024243.jpg
# http://images.cocodataset.org/val2017/000000066231.jpg
# http://images.cocodataset.org/val2017/000000014007.jpg
# http://images.cocodataset.org/val2017/000000452793.jpg
# http://images.cocodataset.org/val2017/000000282296.jpg
# http://images.cocodataset.org/val2017/000000491216.jpg
# http://images.cocodataset.org/val2017/000000423123.jpg
# http://images.cocodataset.org/val2017/000000404191.jpg
# http://images.cocodataset.org/val2017/000000132329.jpg
# http://images.cocodataset.org/val2017/000000052996.jpg
# http://images.cocodataset.org/val2017/000000498463.jpg
# http://images.cocodataset.org/val2017/000000000802.jpg
# http://images.cocodataset.org/val2017/000000028452.jpg
# http://images.cocodataset.org/val2017/000000313130.jpg
# http://images.cocodataset.org/val2017/000000273712.jpg
# http://images.cocodataset.org/val2017/000000512330.jpg
# http://images.cocodataset.org/val2017/000000554838.jpg
# http://images.cocodataset.org/val2017/000000280930.jpg
# http://images.cocodataset.org/val2017/000000237928.jpg
# http://images.cocodataset.org/val2017/000000187271.jpg
# http://images.cocodataset.org/val2017/000000150417.jpg
# http://images.cocodataset.org/val2017/000000057238.jpg
# http://images.cocodataset.org/val2017/000000231339.jpg
# http://images.cocodataset.org/val2017/000000506310.jpg
# http://images.cocodataset.org/val2017/000000502732.jpg

# %%
img_ids
# Out:
# [429598,
#  159791,
#  446522,
#  537672,
#  215114,
#  73326,
#  170116,
#  349837,
#  349837,
#  243344,
#  168593,
#  168593,
#  117908,
#  194724,
#  435880,
#  459954,
#  24243,
#  66231,
#  14007,
#  452793,
#  282296,
#  491216,
#  423123,
#  404191,
#  132329,
#  52996,
#  498463,
#  802,
#  28452,
#  313130,
#  273712,
#  512330,
#  554838,
#  280930,
#  237928,
#  187271,
#  150417,
#  57238,
#  231339,
#  506310,
#  502732]
