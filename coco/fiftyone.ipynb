# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="validation",
    label_types=["segmentations"],
    classes=["cat", "dog"],
    max_samples=25,
)
# Out:
# Downloading split 'validation' to 'C:\Users\nbknt\fiftyone\coco-2017\validation' if necessary
# Found annotations at 'C:\Users\nbknt\fiftyone\coco-2017\raw\instances_val2017.json'
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#  100% |███████████████████| 25/25 [380.3ms elapsed, 0s remaining, 65.7 samples/s]
# Dataset 'coco-2017-validation-25' created

# %%
type(dataset)
# Out:
# fiftyone.core.dataset.Dataset

# %%
dataset.first()
# Out:
# <Sample: {
#     'id': '620ee17ad036ca1b9fa4cceb',
#     'media_type': 'image',
#     'filepath': 'C:\\Users\\nbknt\\fiftyone\\coco-2017\\validation\\data\\000000022892.jpg',
#     'tags': BaseList(['validation']),
#     'metadata': <ImageMetadata: {
#
#         'size_bytes': None,
#
#         'mime_type': None,
#
#         'width': 500,
#
#         'height': 334,
#
#         'num_channels': None,
#
#     }>,
#     'ground_truth': <Detections: {
#
#         'detections': BaseList([
#
#             <Detection: {
#
#
#                 'id': '620ee17ad036ca1b9fa4cce6',
#
#
#                 'attributes': BaseDict({}),
#
#
#                 'tags': BaseList([]),
#
#
#                 'label': 'dog',
#
#
#                 'bounding_box': BaseList([
#
#
#                     0.07124,
#
#
#                     0.2275449101796407,
#
#
#                     0.5067,
#
#
#                     0.6579640718562874,
#
#
#                 ]),
#
#
#                 'mask': array([[False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        ...,
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False]]),
#
#
#                 'confidence': None,
#
#
#                 'index': None,
#
#
#                 'supercategory': 'animal',
#
#
#                 'iscrowd': 0,
#
#
#             }>,
#
#             <Detection: {
#
#
#                 'id': '620ee17ad036ca1b9fa4cce7',
#
#
#                 'attributes': BaseDict({}),
#
#
#                 'tags': BaseList([]),
#
#
#                 'label': 'potted plant',
#
#
#                 'bounding_box': BaseList([
#
#
#                     0.40472,
#
#
#                     0.6531437125748503,
#
#
#                     0.49798000000000003,
#
#
#                     0.3378443113772455,
#
#
#                 ]),
#
#
#                 'mask': array([[False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        ...,
#
#
#                        [False, False, False, ...,  True,  True, False],
#
#
#                        [False, False, False, ...,  True,  True, False],
#
#
#                        [False, False, False, ...,  True, False, False]]),
#
#
#                 'confidence': None,
#
#
#                 'index': None,
#
#
#                 'supercategory': 'furniture',
#
#
#                 'iscrowd': 0,
#
#
#             }>,
#
#             <Detection: {
#
#
#                 'id': '620ee17ad036ca1b9fa4cce8',
#
#
#                 'attributes': BaseDict({}),
#
#
#                 'tags': BaseList([]),
#
#
#                 'label': 'cat',
#
#
#                 'bounding_box': BaseList([
#
#
#                     0.4755,
#
#
#                     0.07029940119760479,
#
#
#                     0.5229,
#
#
#                     0.6903293413173652,
#
#
#                 ]),
#
#
#                 'mask': array([[False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        ...,
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False]]),
#
#
#                 'confidence': None,
#
#
#                 'index': None,
#
#
#                 'supercategory': 'animal',
#
#
#                 'iscrowd': 0,
#
#
#             }>,
#
#             <Detection: {
#
#
#                 'id': '620ee17ad036ca1b9fa4cce9',
#
#
#                 'attributes': BaseDict({}),
#
#
#                 'tags': BaseList([]),
#
#
#                 'label': 'dining table',
#
#
#                 'bounding_box': BaseList([
#
#
#                     0.6946,
#
#
#                     0.6864071856287425,
#
#
#                     0.3054,
#
#
#                     0.3020958083832336,
#
#
#                 ]),
#
#
#                 'mask': array([[False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        ...,
#
#
#                        [False,  True,  True, ...,  True,  True,  True],
#
#
#                        [ True,  True,  True, ...,  True,  True,  True],
#
#
#                        [False, False, False, ...,  True,  True,  True]]),
#
#
#                 'confidence': None,
#
#
#                 'index': None,
#
#
#                 'supercategory': 'furniture',
#
#
#                 'iscrowd': 0,
#
#
#             }>,
#
#             <Detection: {
#
#
#                 'id': '620ee17ad036ca1b9fa4ccea',
#
#
#                 'attributes': BaseDict({}),
#
#
#                 'tags': BaseList([]),
#
#
#                 'label': 'chair',
#
#
#                 'bounding_box': BaseList([
#
#
#                     0.6282000000000001,
#
#
#                     0.0,
#
#
#                     0.3718,
#
#
#                     0.7772155688622754,
#
#
#                 ]),
#
#
#                 'mask': array([[False, False, False, ...,  True,  True,  True],
#
#
#                        [False, False, False, ...,  True,  True,  True],
#
#
#                        [False, False, False, ...,  True,  True,  True],
#
#
#                        ...,
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False],
#
#
#                        [False, False, False, ..., False, False, False]]),
#
#
#                 'confidence': None,
#
#
#                 'index': None,
#
#
#                 'supercategory': 'furniture',
#
#
#                 'iscrowd': 0,
#
#
#             }>,
#
#         ]),
#
#     }>,
# }>
